# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()
print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin: 15.1 g/dL            (Normal:	13.5-17.5)
# Hematocrit: 44%                  (Nor

# %%
extraction_prompt = f"""
You are a medical data extaction assistant.
from the blood report below, extract all test values and classify each one as HIGH, LOW, NORMAL based on the reference range provided in the report.

Format your response as:
- Test Name : value | status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== Stage 1: Extracted Values ===")
print(extracted_values)
# Out:
# === Stage 1: Extracted Values ===
# Here is the extracted information from the blood report:
#
# - Hemoglobin : 15.1 g/dL | status: NORMAL | Reference: 13.5-17.5
# - Hematocrit : 44% | status: NORMAL | Reference: 41-53%
# - WBC : 6.8 x10^3/uL | status: NORMAL | Reference: 4.5-11.0
# - Platelets : 220 x10^3/uL | status: NORMAL | Reference: 150-400
# - Total Cholesterol : 238 mg/dL | status: HIGH | Reference: <200
# - LDL Cholesterol : 162 mg/dL | status: HIGH | Reference: <100
# - HDL Cholesterol : 36 mg/dL | status: LOW | Reference: >40
# - Triglycerides : 188 mg/dL | status: HIGH | Reference: <150
# - Glucose (Fasting) : 92 mg/dL | status: NORMAL | Reference: 70-99
# - HbA1c : 5.3% | status: NORMAL | Reference: <5.7%
# - Creatinine : 1.8 mg/dL | status: HIGH | Reference: 0.7-1.3
# - eGFR : 82 mL/min | status: NORMAL | Reference: >60
# - ALT : 28 U/L | status: NORMAL | Reference: 7 - 40
# - AST : 25 U/L | status: NORMAL | Reference: 10 - 40
# - Bilirubin total : 28 U/L | status: HIGH | Reference: 0.2 - 1.2

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietery habits.

Based on the blood work analysis below, write:
1. A short health summary in 3 lines explaining the patient's condition in simple language.
2. A short, practical Indian dient plan having only two sections (1) food to avoid (2) food to eat more of
    Do not include any other sections in diet plan.

Blood Work Anaysis: {extracted_values}
"""

diet_response = llm.invoke(diet_prompt)
print("=== STAGE2: Health Summary and Diet Plan")
print(diet_response.text)
# Out:
# === STAGE2: Health Summary and Diet Plan
# Here is your health summary and a practical Indian diet plan:
#
# **1. Health Summary:**
# Your blood tests show elevated cholesterol and triglyceride levels, which increases your risk for heart-related issues. Additionally, your creatinine and bilirubin are mildly high, suggesting your kidneys and liver need some extra attention. By making specific dietary changes, we can effectively work towards improving these markers and your overall well-being.
#
# **2. Indian Diet Plan:**
#
# **Foods to Avoid:**
# *   Deep-fried Indian snacks like samosas, pakoras, puri, and bhature.
# *   Excessive use of ghee, butter, full-fat dairy products (full-cream milk, paneer, mawa), and creamy gravies.
# *   Sugary sweets (mithai), desserts, sweetened beverages, and processed foods like biscuits and cakes.
# *   Refined flour (maida) items such as white bread, naan, and pastries.
# *   Red meats, processed meats, and salty items like pickles and papads.
# *   Alcohol.
#
# **Foods to Eat More Of:**
# *   **Whole Grains:** Oats, brown rice, millets (bajra, jowar, ragi), and whole wheat roti/chapati.
# *   **Fruits and Vegetables:** Plenty of fresh, seasonal fruits and all types of vegetables, especially leafy greens.
# *   **Lentils and Legumes:** Include a variety of dals, chickpeas (chole), kidney beans (rajma), and sprouts daily.
# *   **Lean Proteins:** Skinless chicken, fish (especially fatty fish like mackerel or salmon if available), tofu, and low-fat paneer in moderation.
# *   **Healthy Fats:** A small handful of nuts (almonds, walnuts), seeds (flax seeds, chia seeds), and cook with minimal healthy oils like mustard oil or rice bran oil.
# *   **Dairy:** Skim milk or low-fat curd/yogurt.
# *   **Hydration:** Drink plenty of water throughout the day.
